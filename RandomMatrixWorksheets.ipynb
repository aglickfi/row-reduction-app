# %%
import numpy as np

def big_nice_2x3(high, low):

    #Generates a (uniformly) random matrix

    while True:

        matrix = np.random.randint(low, high+1, size=(2,3))
        det = matrix[0][0]*matrix[1][1] - matrix[0][1]*matrix[1][0]

        if det != 0:
            break



    #Ensures the final matrix has a nice RREF

    b1 = matrix[0][2]
    b2 = matrix[1][2]

    matrix[0][2] = det*b1
    matrix[1][2] = det*b2

    return matrix

def small_nice_2x3(high, low):

    #Generates a (uniformly) random matrix

    while True: 

        matrix = np.random.randint(low, high+1, size=(2,3))

        #Checking for small determinant

        det = matrix[0][0]*matrix[1][1] - matrix[0][1]*matrix[1][0]

        if np.abs(det) <= 5 and det != 0:

            break

    #Ensures the final matrix has a nice RREF
    
    b1 = matrix[0][2]
    b2 = matrix[1][2]

    matrix[0][2] = det*b1
    matrix[1][2] = det*b2

    return matrix

print(f"{small_nice_2x3(5,-5)}")


#def nice_matrix(m,n):
# Out:
# [[-2  1 -4]
#  [-3  1 -4]]
